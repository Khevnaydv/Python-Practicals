# %%
#1. Write and run the small statement - "Hello! My name is ----- and my hobby is -----" 
print("Hello! My name is Khevna Yadav and my hobby is doing art and craft.")
# Out:
# Hello! My name is Khevna Yadav and my hobby is doing art and craft.

# %%
#2. Print the comments
# This is a single-line comment
print("Hello World")
"""This is a multi-line comment.
It can contain multiple lines."""
print("Hello Python")
# Out:
# Hello World
# Hello Python

# %%
#3. Display integer, float, String, Boolean
integer = 11
float = 11.5
string = "Python"
boolean = True

print(integer)
print(float)
print(string)
print(boolean)
# Out:
# 11
# 11.5
# Python
# True

# %%
#4. Convert float to integer, String to integer, Boolean to integer 
# Float to integer
float_value = 3.75
integer_from_float = int(float_value)

# String to integer
string_value = "45"
integer_from_string = int(string_value)

# Boolean to integer
boolean_value = True
integer_from_boolean = int(boolean_value)

print(float_value)
print(string_value)
print(boolean_value)
# Out:
# 3.75
# 45
# True

# %%
#5. Provide the simple operations performed in the calculator (addition, subtraction, multiplacation, divison)
a = 20
b = 5

addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b 

print(addition)
print(subtraction)
print(multiplication)
print(division)
# Out:
# 25
# 15
# 100
# 4.0

# %%
#6. Write an expression that calculates how many hours there are in 160 minutes
hours = 160 / 60
print("Number of hours:", hours)
# Out:
# Number of hours: 2.6666666666666665
